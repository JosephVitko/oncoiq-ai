# %%
from fastai import *
from fastai.vision import *
from fastai.metrics import error_rate
from images_path import images_path
import os
import pandas as pd
import numpy as np

# %%
import torch
if torch.cuda.is_available():
    print('PyTorch found cuda')
else:
    print('PyTorch could not find cuda')
# Out:
# PyTorch found cuda

# %%
# setting up path for training data
path = Path(images_path)
pattern = r'([^/_]+).png$'
fnames = get_files(path, recurse=True)
tfms = get_transforms(flip_vert=True, max_warp=0., max_zoom=0., max_rotate=0.)
path.ls()
# Out:
# [WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/10253'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/10254'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/10255'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/10256'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/10257'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/10258'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/10259'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/10260'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/10261'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/10262'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/10264'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/10268'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/10269'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/10272'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/10273'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/10274'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/10275'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/10276'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/10277'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/10278'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/10279'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/10282'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/10285'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/10286'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/10288'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/10290'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/10291'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/10292'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/10293'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/10295'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/10299'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/10300'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/10301'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/10302'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/10303'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/10304'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/10305'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/10306'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/10307'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/10308'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12241'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12242'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12626'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12748'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12749'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12750'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12751'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12752'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12810'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12811'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12817'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12818'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12819'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12820'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12821'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12822'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12823'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12824'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12826'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12867'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12868'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12869'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12870'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12871'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12872'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12873'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12875'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12876'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12877'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12878'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12879'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12880'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12881'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12882'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12883'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12884'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12886'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12890'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12891'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12892'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12893'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12894'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12895'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12896'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12897'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12898'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12900'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12901'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12905'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12906'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12907'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12908'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12909'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12910'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12911'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12929'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12930'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12931'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12932'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12933'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12934'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12935'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12947'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12948'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12949'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12951'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12954'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/12955'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/13018'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/13019'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/13020'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/13021'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/13022'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/13023'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/13024'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/13025'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/13106'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/13400'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/13401'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/13402'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/13403'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/13404'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/13458'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/13459'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/13460'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/13461'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/13462'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/13591'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/13613'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/13616'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/13617'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/13666'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/13687'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/13688'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/13689'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/13691'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/13692'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/13693'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/13694'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/13916'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/14078'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/14079'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/14081'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/14082'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/14153'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/14154'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/14155'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/14156'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/14157'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/14188'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/14189'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/14190'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/14191'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/14192'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/14209'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/14210'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/14211'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/14212'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/14213'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/14304'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/14305'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/14306'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/14321'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/15471'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/15472'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/15473'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/15510'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/15512'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/15513'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/15514'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/15515'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/15516'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/15632'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/15633'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/15634'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/15839'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/15840'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/15902'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/15903'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/16014'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/16085'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/16165'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/16166'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/16167'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/16531'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/16532'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/16533'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/16534'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/16550'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/16551'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/16552'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/16553'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/16554'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/16555'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/16568'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/16569'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/16570'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/16895'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/16896'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/8863'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/8864'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/8865'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/8867'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/8913'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/8914'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/8916'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/8917'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/8918'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/8950'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/8951'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/8955'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/8956'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/8957'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/8959'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/8974'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/8975'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/8980'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/8984'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9022'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9023'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9029'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9035'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9036'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9037'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9041'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9043'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9044'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9073'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9075'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9076'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9077'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9078'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9081'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9083'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9123'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9124'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9125'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9126'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9135'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9173'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9174'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9175'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9176'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9177'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9178'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9181'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9225'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9226'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9227'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9228'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9250'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9254'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9255'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9256'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9257'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9258'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9259'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9260'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9261'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9262'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9265'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9266'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9267'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9290'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9291'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9319'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9320'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9321'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9322'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9323'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9324'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9325'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9344'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9345'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9346'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9347'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9381'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9382'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/9383'),
#  WindowsPath('C:/Users/Joseph/Desktop/oncoiq/breast_histopathology/IDC_regular_ps50_idx5')]

# %%
# Data loading for training
np.random.seed(40)
data = ImageDataBunch.from_name_re(path, fnames, pattern, ds_tfms=tfms, size=50, bs=64, num_workers=4).normalize()

# %%
# data exploration
data.show_batch(rows=3, figsize=(7, 6), recompute_scale_factor=True)

# %%
# print data
print(data.classes)
len(data.classes)
data.c
# Out:
# ['class0', 'class1']
# 2

# %%
data
# Out:
# ImageDataBunch;
#
# Train: LabelList (444039 items)
# x: ImageList
# Image (3, 50, 50),Image (3, 50, 50),Image (3, 50, 50),Image (3, 50, 50),Image (3, 50, 50)
# y: CategoryList
# class0,class0,class0,class0,class0
# Path: C:\Users\Joseph\Desktop\oncoiq\breast_histopathology;
#
# Valid: LabelList (111009 items)
# x: ImageList
# Image (3, 50, 50),Image (3, 50, 50),Image (3, 50, 50),Image (3, 50, 50),Image (3, 50, 50)
# y: CategoryList
# class0,class1,class0,class0,class0
# Path: C:\Users\Joseph\Desktop\oncoiq\breast_histopathology;
#
# Test: None

# %%
# create model
learn = cnn_learner(data, models.resnet18, metrics=[accuracy], model_dir=Path('../kaggle/working'), path=Path("."))

# %%
learn.model.cuda()
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (1): Sequential(
#     (0): AdaptiveConcatPool2d(
#       (ap): AdaptiveAvgPool2d(output_size=1)
#       (mp): AdaptiveMaxPool2d(output_size=1)
#     )
#     (1): Flatten()
#     (2): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=1024, out_features=512, bias=True)
#     (5): ReLU(inplace=True)
#     (6): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.5, inplace=False)
#     (8): Linear(in_features=512, out_features=2, bias=True)
#   )
# )

# %%
# find LR
learn.lr_find()
learn.recorder.plot(suggestions=True)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='88' class='' max='6938' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       1.27% [88/6938 01:12<1:33:49 2.9795]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
# train model
lr1 = 1e-3
lr2 = 1e-1
learn.fit_one_cycle(5,slice(lr1,lr2))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.425592</td>
#       <td>0.406855</td>
#       <td>0.845652</td>
#       <td>09:11</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.458625</td>
#       <td>2.765481</td>
#       <td>0.840508</td>
#       <td>08:53</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.375946</td>
#       <td>12.933216</td>
#       <td>0.848283</td>
#       <td>08:36</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.282466</td>
#       <td>3.639484</td>
#       <td>0.880037</td>
#       <td>08:40</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.277926</td>
#       <td>5.186294</td>
#       <td>0.885208</td>
#       <td>08:41</td>
#     </tr>
#   </tbody>
# </table>

# %%
# interpret the results
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()

# %%
learn.export()
learn.model_dir = "/kaggle/working"
learn.save("stage-2", return_path=True)
# Out:
# WindowsPath('/kaggle/working/stage-2.pth')
